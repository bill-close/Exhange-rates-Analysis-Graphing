# %% [markdown]
# ## Describing the daily exchange rates between 1999 and 2021 for the Euro and USD

# %% [markdown]
# ### 1. Introduction
# This dataset is available on Kaggle:
# https://www.kaggle.com/lsind18/euro-exchange-daily-rates-19992020

# %%
import pandas as pd
exchange_rates = pd.read_csv('euro-daily-hist_1999_2020.csv')

# %%
exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2021-01-08               1.5758           1.9558            6.5748
# 1   2021-01-07               1.5836           1.9558            6.5172
# 2   2021-01-06               1.5824           1.9558            6.5119
# 3   2021-01-05               1.5927           1.9558            6.5517
# 4   2021-01-04               1.5928           1.9558            6.3241
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.5543         1.0827                   7.9184              NaN
# 1             1.5601         1.0833                   7.9392              NaN
# 2             1.5640         1.0821                   7.9653              NaN
# 3             1.5651         1.0803                   7.9315              NaN
# 4             1.5621         1.0811                   7.9484              NaN
#
# ...

# %%
exchange_rates.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 5694   1999-01-08               1.8406              NaN               NaN
# 5695   1999-01-07               1.8474              NaN               NaN
# 5696   1999-01-06               1.8820              NaN               NaN
# 5697   1999-01-05               1.8944              NaN               NaN
# 5698   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 5694             1.7643         1.6138                      NaN
# 5695             1.7602         1.6165                      NaN
# 5696             1.7711         1.6116                      NaN
# 5697             1.7965         1.6123                      NaN
# 5698             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# ...

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              5699 non-null   object
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %% [markdown]
# There are 40 columns and 5699 rows to examine.
# Some of the data has null values. Especially for "Greek drachma" (Perhaps consider deleting this one)
# All of the datatypes are objects with the exception of Iceland krona, Romanian leu and Turkish lira which have float64.

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time'},
                      inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)
exchange_rates.head()
# Out:
#         Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0 1999-01-04               1.9100              NaN               NaN
# 1 1999-01-05               1.8944              NaN               NaN
# 2 1999-01-06               1.8820              NaN               NaN
# 3 1999-01-07               1.8474              NaN               NaN
# 4 1999-01-08               1.8406              NaN               NaN
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.8004         1.6168                      NaN          0.58231
# 1             1.7965         1.6123                      NaN          0.58230
# 2             1.7711         1.6116                      NaN          0.58200
# 3             1.7602         1.6165                      NaN          0.58187
# 4             1.7643         1.6138                      NaN          0.58187
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# ...

# %%
euro_to_dollar = exchange_rates[['Time', 'US_dollar']].copy()
euro_to_dollar
# Out:
#            Time US_dollar
# 0    1999-01-04    1.1789
# 1    1999-01-05    1.1790
# 2    1999-01-06    1.1743
# 3    1999-01-07    1.1632
# 4    1999-01-08    1.1659
# ...         ...       ...
# 5694 2021-01-04    1.2296
# 5695 2021-01-05    1.2271
# 5696 2021-01-06    1.2338
# 5697 2021-01-07    1.2276
# 5698 2021-01-08    1.2250
#
# [5699 rows x 2 columns]

# %%
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.3373     6
#           ..
# 1.2598     1
# 1.1954     1
# 1.5812     1
# 1.2101     1
# 1.5471     1
# Name: US_dollar, Length: 3528, dtype: int64

# %% [markdown]
# There are 62 times the character "-" within the dataset

# %% [markdown]
# Lets select all the rows where the US_dollar does not contain the "-"

# %%
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']

# %%
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)
# Out:
# <ipython-input-9-2f8ce020b293>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)

# %%
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5637 entries, 0 to 5698
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       5637 non-null   datetime64[ns]
#  1   US_dollar  5637 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 132.1 KB

# %% [markdown]
# ### 2. Visualising the data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.plot(euro_to_dollar['Time'],
         euro_to_dollar['US_dollar'])
plt.show()

# %% [markdown]
# To smooth out the graph lets calculate the rolling mean

# %%
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()
euro_to_dollar
# Out:
# <ipython-input-12-f53f2edf2241>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Time  US_dollar  rolling_mean
# 0    1999-01-04     1.1789           NaN
# 1    1999-01-05     1.1790           NaN
# 2    1999-01-06     1.1743           NaN
# 3    1999-01-07     1.1632           NaN
# 4    1999-01-08     1.1659           NaN
# ...         ...        ...           ...
# 5694 2021-01-04     1.2296      1.211170
# 5695 2021-01-05     1.2271      1.212530
# 5696 2021-01-06     1.2338      1.213987
# 5697 2021-01-07     1.2276      1.215357
# 5698 2021-01-08     1.2250      1.216557
#
# [5637 rows x 3 columns]

# %% [markdown]
# This is the new plot. It is visually easier to see

# %%
plt.plot(euro_to_dollar['Time'],
         euro_to_dollar['rolling_mean'])
plt.xlabel('Year')
plt.ylabel('Exchange rate from 1 Euro to USD')
plt.title('Exhange rate EUR/USD over 20 years')
plt.show()

# %% [markdown]
# With a rolling average of 30 days applied we can see a more representable graph of the data

# %% [markdown]
# ### 3. Analysis of exchange rates and the US Presidencies of Bush, Obama and Trump

# %% [markdown]
# To do this I will split up the above graph to better address how the exchange was affected in each presidency.
# Bush (2001-2009)
# Obama (2009-2017)
# Trump (2017-2021)

# %%
bush_obama_trump = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2001) & (euro_to_dollar['Time'].dt.year < 2021)]

bush = bush_obama_trump.copy()[bush_obama_trump['Time'].dt.year < 2009]

obama = bush_obama_trump.copy()[(bush_obama_trump['Time'].dt.year >= 2009) & (bush_obama_trump['Time'].dt.year < 2017)]

trump = bush_obama_trump.copy()[(bush_obama_trump['Time'].dt.year >= 2017) & (bush_obama_trump['Time'].dt.year < 2021)]

bush
# Out:
#            Time  US_dollar  rolling_mean
# 521  2001-01-02     0.9423      0.883343
# 522  2001-01-03     0.9530      0.886660
# 523  2001-01-04     0.9458      0.889893
# 524  2001-01-05     0.9545      0.893463
# 525  2001-01-08     0.9497      0.897023
# ...         ...        ...           ...
# 2601 2008-12-23     1.3978      1.303717
# 2602 2008-12-24     1.4005      1.308633
# 2605 2008-12-29     1.4270      1.314450
# 2606 2008-12-30     1.4098      1.319193
# 2607 2008-12-31     1.3917      1.323383
#
# [2046 rows x 3 columns]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1,
                                        figsize=(16,11))
axes = [ax1, ax2, ax3]
titles = ['Bush', 'Obama', 'Trump']

for ax in axes:
    ax.plot(bush_obama_trump['Time'], bush_obama_trump['rolling_mean'], color='grey', alpha=0.6)
    for location in ['right', 'top']:
        ax.spines[location].set_visible(False)
        
ax1.text(730799, 1.8, 'Comparison of the EUR/USD exchange under different presidencies', size=18, weight='bold')

ax1.plot(bush['Time'], bush['rolling_mean'], color='chocolate', linewidth='7')
ax1.text(731799, 1.5, 'Bush', size=14, weight='bold', color='chocolate')
ax1.text(729699, 1, 'EUR USD Exchange', size=10, rotation='90')

ax2.plot(obama['Time'], obama['rolling_mean'], color='blue', linewidth='7')
ax2.text(734799, 1.49, 'Obama', size=14, weight='bold', color='blue')
ax2.text(729699, 1, 'EUR USD Exchange', size=10, rotation='90')

ax3.plot(trump['Time'], trump['rolling_mean'], color='red', linewidth='7')
ax3.text(736799, 1.35, 'Trump', size=14, weight='bold', color='red')
ax3.text(729699, 1, 'EUR USD Exchange', size=10, rotation='90')
ax3.text(733999, 0.65, 'Year', size=18)

#plt.grid()      Personally, I didnt like the grid overlay

### Adding a signature
ax3.text(729999, 0.52, 'Bill-Close' + ' '*130 + 'DataSource: European Central Bank',
        color = '#f0f0f0', backgroundcolor = '#4d4d4d',
        size=14)          

plt.show()

# %% [markdown]
# ### 4. Summary

# %% [markdown]
# This project has explored the exchange rate between the EURO and USD between 1999 and 2021. Here I downloaded, cleaned and explored the data using graphical representation to depict the changes. I wanted to then split up the data according to the different presidencies of Bush, Obama and Trump. In doing so I could show these results in the final graph in bold ontop of a grey timeline. This shows there was an increase during Bushes administration, a decrease during the Obama administration and a slight increase during Trumps administration.
#
# Thank you for reading!
#
# Cheers,
# Bill Close
